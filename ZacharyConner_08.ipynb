# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
zipcode = gpd.read_file('C:\\Users\zconn\Downloads\manh_pluto_and_zip_codes\manh_pluto.shp')

# %%
zipcode.head()
# Out:
#   Borough  Block   Lot   CD CT2010 CB2010 SchoolDist  Council  ZipCode  \
# 0      MN   1545    52  108    138   4000         02        5    10028
# 1      MN    723  7501  104     93   6000         02        3    10001
# 2      MN   1680    48  111    170   5000         04        8    10029
# 3      MN   1385    32  108    130   2003         02        4    10021
# 4      MN   1197    27  107    169   5000         03        6    10024
#
#   FireComp  ...  TaxMap  EDesigNum        APPBBL     APPDate PLUTOMapID  \
# 0     E022  ...   10515       None  0.000000e+00        None          1
# 1     E003  ...   10302       None  1.007230e+09  11/30/2006          1
# 2     E091  ...   10605       None  0.000000e+00        None          1
# 3     E039  ...   10508       None  0.000000e+00        None          1
# 4     E074  ...   10408       None  0.000000e+00        None          1
#
#   Version MAPPLUTO_F  SHAPE_Leng    SHAPE_Area  \
# 0    16v1          0  260.428942   2867.154706
# ...

# %%
zip_group = zipcode.groupby(['ZipCode']).mean()

# %%
zip_group.LotArea
# Out:
# ZipCode
# 0         45004.897059
# 10001     12390.864136
# 10002     10776.675548
# 10003      5149.895666
# 10004    130695.920354
# 10005     29927.706667
# 10006     16642.621212
# 10007     19027.125541
# 10009      8757.838906
# 10010     10730.279412
# 10011      6355.580348
# 10012      4738.022356
# 10013      5679.506782
# 10014      6219.464506
# 10016      7234.956108
# 10017     13689.688559
# 10018     12988.357724
# 10019     12790.259570
# 10020     65921.400000
# 10021      5418.004274
# 10022      7404.218232
# 10023      7348.330136
# 10024      6517.600802
# 10025     11066.677440
# 10026      5762.160606
# 10027      7359.407003
# 10028      5116.600167
# 10029     10473.496560
# 10030      4169.553078
# 10031      8446.070632
# 10032     11679.808260
# 10033     17104.480720
# 10034     48126.524412
# 10035     24375.456081
# 10036      9481.683544
# 10037     12223.981723
# 10038     18147.385915
# 10039     22245.895425
# 10040     13808.647196
# ...
